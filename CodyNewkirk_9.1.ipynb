# %%
# 9.1-Function.ipynb
# Cody Newkirk
# SDEV220

# Define a function that returns a list of good characters
def good():
    return ['Harry', 'Ron', 'Hermione']

# Call the function and print the result
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
# 7.7-List.ipynb
# Cody Newkirk
# SDEV220

# Create the list
things = ["mozzarella", "cinderella", "salmonella"]

# Capitalize the person
things[1] = things[1].capitalize()

# Uppercase the cheese
things[0] = things[0].upper()

# Delete the disease
del things[2]

# Nobel Prize moment
print("Please gracefully accept the Nobel Peace Prize.")

# Print the updated list
print(things)
# Out:
# Please gracefully accept the Nobel Peace Prize.
# ['MOZZARELLA', 'Cinderella']
